# %%
print('안녕하세요^^')
# Out:
# 안녕하세요^^

# %%
# !pip install openai==0.28
# Out:
# Requirement already satisfied: openai==0.28 in /usr/local/lib/python3.10/dist-packages (0.28.0)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai==0.28) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai==0.28) (4.66.4)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai==0.28) (3.9.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (2024.7.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (4.0.3)

# %%
import openai

# openai key 입력
OPENAI_API_KEY = 'open ai key를 입력하세요 '

# %%
OPENAI_API_KEY = ''
openai.api_key = OPENAI_API_KEY

# %%
model = 'gpt-3.5-turbo'
query = '''
나의 MBTI : estp
상대방 이름 : 카리나
관계 : 연인
상황 : 만난 지 100일 된 상황
질문 : 100일 기념 선물로 무엇이 좋을거 같아? 보통 어떤 거 선물하지?
'''
# few shot
messages = [
    {'role': 'system', 'content': '연예전문상담가'},
    {'role': 'user', 'content': query},
]
try:
    response = openai.ChatCompletion.create(
        model = model,
        messages=messages,
        temperature=0
        # 0 에 가까울 수록 일반적인 답변.
        # 0-1 1에 가까우면 창의적 답변(할루시네이션 가능성 존재)
    )
    # print(response)
    print(response.choices[0].message['content'])
except Exception as e:
    print(f'에러가 발생했어요.: {e}')
# Out:
# 카리나와의 100일 기념 선물을 준비하시는 건 멋진 아이디어네요! ESTP 유형의 사람들은 즉흥적이고 활동적인 성향을 가지고 있어서, 카리나에게 특별한 경험을 선물해주는 것이 좋을 것 같습니다.
#
# 1. 여행 혹은 데이트 쿠폰: 카리나와 함께 즐거운 시간을 보낼 수 있는 여행이나 데이트 쿠폰을 선물해보세요. 예를 들어, 레스토랑 예약, 영화 티켓, 스파 일정 등을 포함한 쿠폰을 만들어서 함께 즐길 수 있는 시간을 선물해보세요.
#
# 2. 특별한 액티비티 체험: 카리나가 좋아할 만한 액티비티를 예약해주는 것도 좋은 아이디어입니다. 예를 들어, 요가 수업, 요리 수업, 서핑 레슨 등을 예약해주어 함께 새로운 경험을 할 수 있도록 도와주세요.
#
# 3. 특별한 아이템: 카리나가 좋아하는 브랜드의 제품이나 특별한 소장품을 선물해도 좋습니다. 예를 들어, 특별한 액세서리, 향수, 책, 음악 CD 등을 고려해보세요.
#
# 100일 기념 선물은 서로의 관계를 더욱 특별하게 만들어주는 기회이니, 카리나가 좋아할 만한 것을 고려하여 선물해보시기 바랍니다. 상대방을 생각하고 준비한 선물은 더욱 의미있고 감동적일 것입니다. 축하드립니다!

# %% [markdown]
# MBTI 입력받는 프로그램 (초창기 모델V.0)

# %%
# 사용자로부터  MBTI 관계, 상황 등 입력 받기

input('내 MBTI: ').upper()  # 대문자로 일괄 변환
# Out:
# 내 MBTI: ENFP
# 'ENFP'

# %%
my_mbti = input('내 MBTI: ').upper()
your_mbti = input('상대방 MBTI: ').upper()
your_name = input('상대방 이름: ')
relation = input('관계: ')
situation = input('상황: ')
question = input('질문: ')

query = f'''
나의 MBTI : {my_mbti}
상대방 MBTI : {your_mbti}
상대방 이름 : {your_name}
관계 : {relation}
상황 : {situation}
질문 : {question}
'''
# Out:
# 내 MBTI: ENFP
# 상대방 MBTI: ESFJ
# 상대방 이름: BH
# 관계: 커플
# 상황: 나는 짜장면이 먹고싶은데, 계속 국밥을 먹으러 가자고 해
# 질문: 이럴때는 어떻게 합의해야 할까?

# %%
# few shot
messages = [
    {'role': 'system', 'content': '연예전문상담가'},
    {'role': 'user', 'content': query},
]
try:
    response = openai.ChatCompletion.create(
        model = model,
        messages=messages,
        temperature=0
        # 0 에 가까울 수록 일반적인 답변.
        # 0-1 1에 가까우면 창의적 답변(할루시네이션 가능성 존재)
    )
    # print(response)
    print(response.choices[0].message['content'])
except Exception as e:
    print(f'에러가 발생했어요.: {e}')
# Out:
# ENFP와 ESFJ는 대체로 서로를 이해하고 존중하는 관계를 형성할 수 있습니다. 이 상황에서는 상대방의 선호도를 고려하면서 상호 합의점을 찾는 것이 중요합니다.
#
# 1. 이해와 존중: 먼저 BH의 입장을 이해하고 존중해줍니다. 그들이 국밥을 좋아하는 이유를 듣고 이해해보세요.
#
# 2. 솔직한 의사 표현: 짜장면을 먹고 싶다는 당신의 솔직한 의사를 표현해보세요. BH에게 당신의 마음을 열고 솔직하게 전달하는 것이 중요합니다.
#
# 3. 타협과 합의: 양쪽이 서로의 의견을 듣고 타협할 부분을 찾아보세요. 예를 들어, 한 번은 짜장면을 먹고 다음에는 국밥을 먹는 것과 같이 상호 타협을 통해 합의점을 찾을 수 있습니다.
#
# 4. 즐거운 경험으로 변화 주기: 때로는 새로운 경험을 통해 상대방의 선호도를 바꿀 수도 있습니다. 짜장면 맛집이나 국밥 맛집을 함께 찾아보며 새로운 경험을 만들어보는 것도 좋은 방법일 수 있습니다.
#
# 이러한 방법을 통해 상대방과의 의견 차이를 해결하고 즐거운 식사 시간을 보낼 수 있기를 바랍니다.

# %% [markdown]
# 나만의 연예상담 봇_love_coach

# %%
my_mbti = input('내 MBTI: ').upper()
your_mbti = input('상대방 MBTI: ').upper()
your_name = input('상대방 이름: ')
relation = input('관계: ')
situation = input('상황: ')
question = input('질문: ')

query = f'''
나의 MBTI : {my_mbti}
상대방 MBTI : {your_mbti}
상대방 이름 : {your_name}
관계 : {relation}
상황 : {situation}
질문 : {question}
'''

# few shot
messages = [
    {'role': 'system', 'content': '연예전문상담가'},
    {'role': 'user', 'content': query},
]

print('답변을 준비중입니다. 잠시만 기다려 주세요')

response = openai.ChatCompletion.create(
        model = model,
        messages=messages,
        temperature=0.7
)

answer = response.choices[0].message['content']
messages.append({'role' : 'assistant', 'content':answer})

print(answer)
# Out:
# 내 MBTI: INFP
# 상대방 MBTI: ISTJ
# 상대방 이름: BH
# 관계: 연인
# 상황: 말다툼
# 질문: 화해하고 싶어.. 해결 방안 제시해줘
# 답변을 준비중입니다. 잠시만 기다려 주세요
# INFP와 ISTJ는 매우 다른 성향을 가진 유형이기 때문에 말다툼 상황에서 서로를 이해하고 화해하는 것이 조금 어려울 수 있습니다. 하지만 화해하고 싶다는 마음은 이미 좋은 시작입니다. 화해를 위해 아래의 방안을 제시해드립니다.
#
# 1. 솔직하게 대화하기: 말다툼의 원인이 무엇인지 파악하고 상대방에게 솔직하게 자신의 감정과 생각을 털어놓는 것이 중요합니다. 서로가 어떤 점에서 불편함을 느끼는지 이해하고 이해를 도울 수 있는 대화를 나누어보세요.
#
# 2. 상대방의 의견에 귀 기울이기: ISTJ는 현실적이고 논리적인 성향을 가지고 있으므로, BH의 의견을 경청하고 이해하려는 노력을 기울이는 것이 중요합니다. 서로의 입장을 존중하고 이해하는 것이 화해의 첫걸음이 될 수 있습니다.
#
# 3. 공통의 관심사 찾기: INFP와 ISTJ는 성향이 다르지만, 서로를 이해하고 존중하는 공통된 가치를 찾아보는 것도 중요합니다. 서로의 관심사나 가치관을 공유하며 서로를 더 잘 이해할 수 있는 기회를 만들어보세요.
#
# 4. 사과와 용서: 말다툼이 있었다면 상대방에게 사과하고, 상대방의 용서를 구하는 것도 중요합니다. 양쪽 모두가 자신의 잘못을 인정하고 용서하며 새로운 시작을 할 수 있도록 노력해보세요.
#
# 이러한 노력과 소통을 통해 서로를 이해하고 존중하는 관계를 만들어가는 것이 중요합니다. 어려운 상황이지만 서로를 위한 노력과 이해가 화해로 이어지길 바랍니다.

# %%
my_mbti = input('내 MBTI: ').upper()
your_mbti = input('상대방 MBTI: ').upper()
your_name = input('상대방 이름: ')
relation = input('관계: ')
situation = input('상황: ')
question = input('질문: ')

query = f'''
나의 MBTI : {my_mbti}
상대방 MBTI : {your_mbti}
상대방 이름 : {your_name}
관계 : {relation}
상황 : {situation}
질문 : {question}
'''

# few shot
messages = [
    {'role': 'system', 'content': '연예전문상담가'},
    {'role': 'user', 'content': query},
]

print('답변을 준비중입니다. 잠시만 기다려 주세요')

response = openai.ChatCompletion.create(
        model = model,
        messages=messages,
        temperature=0.7
)

answer = response.choices[0].message['content']
messages.append({'role' : 'assistant', 'content':answer})

print(answer)

# 질문이 끊기지 않고 계속 하도록 while 사용(multi-turn)

while True:
  # 사용자로부터 질문을 받는다
  question = input('질문: ')
  query = f'Q: {question}'
  # 질문을 메시지 배열에 추가
  messages.append({'role':'user','content':query})
  # chat agt API 호출>>응답
  print('답변을 준비중이에요')
  response = openai.ChatCompletion.create(
        model = model,
        messages=messages,
        temperature=0.7
)
  answer = response.choices[0].message['content']
  # 응답을 출력
  print('-'*80)
  messages.append({'role' : 'assistant', 'content':answer})
  print(answer)
  # 사용자에게 계속 질문할건지 확인하기

  while True:
    q = input('더 질문하실건가요?(y/n):').lower() # 입력된 영어 문자를 전부 소문자로 변환
    if q in ['y','n','ㅜ','ㅛ']:
      break # 정지조건
    else:
      print('유효한 입력이 아닙니다. y나 n 중 선택해서 다시 입력해 주세요')

  if q in ['n','ㅜ']:
      print('종료합니다')
      break
# Out:
# 내 MBTI: enfp
# 상대방 MBTI: esfj
# 상대방 이름: bh
# 관계: 연인
# 상황: 공부를 안하여고 해
# 질문: 공부를 안하려고 하는데, 이럴때는 어떻게 해야해, 해결 방안 제시해줘
# 답변을 준비중입니다. 잠시만 기다려 주세요
# 안녕하세요! ENFP와 ESFJ는 서로를 보와해주는 관계로, 상대방인 bh가 공부를 안하려고 한다는 상황에서 당신이 도와주고자 하는 것은 좋은 점입니다. 이런 상황에서는 다음과 같은 해결 방안을 제시해볼 수 있습니다:
#
# 1. 이해와 동기 부여: 먼저 상대방의 입장을 이해하고, 공부를 안하려고 하는 이유를 파악해보세요. 그리고 그 이유를 이해하고 공감해준 뒤, 그에게 동기를 부여해주세요. 예를 들어, 공부를 통해 더 나은 미래를 위해 노력하는 것이 중요하다는 점을 강조해보세요.
#
# 2. 협력과 도움 제공: 상대방이 공부하기 힘들어하는 부분이 있을 수 있습니다. 그럴 때는 상대방이 부족한 부분을 파악하고, 협력하여 도움을 제공해주세요. 함께 공부하는 것이 더 효과적일 수 있습니다.
#
# 3. 긍정적인 강조와 칭찬: 상대방이 노력하고 성과를 내면 그것에 대해 긍정적으로 강조해주고 칭찬해주세요. 상대방이 노력한 것을 인정받고 보상을 받는 것은 더욱 동기부여가 될 수 있습니다.
#
# 4. 목표 설정과 계획 수립: 상대방과 함께 목표를 설정하고 그에 맞는 계획을 세워주세요. 목표와 계획이 명확하면, 공부에 대한 방향성을 잃지 않고 집중할 수 있습니다.
#
# 5. 유연한 접근과 이해: 상대방이 공부하기 힘들어하는 상황에 대해 이해하고, 유연하게 접근해주세요. 강제로 하라고 하는 것보다는 상대방의 의견을 경청하고 협의하여 해결책을 찾는 것이 중요합니다.
#
# 이런 방법들을 통해 상대방인 bh가 공부를 할 수 있도록 도와주세요. 서로의 차이를 이해하고 협력하여 문제를 해결하는 것이 중요합니다. 함께 노력하고 서로를 응원하는 관계가 되길 바랍니다. 부디 좋은 결과가 있기를 기대합니다!
# 질문: n
# 답변을 준비중이에요
# --------------------------------------------------------------------------------
# 죄송합니다, "n"이라는 질문이나 내용이 이해되지 않습니다. 무엇을 도와드릴까요? 추가적인 정보나 질문이 있으시면 알려주세요!
# 더 질문하실건가요?(y/n):n
# 종료합니다
